# %%
#In which city the purchase is maximum & minimum
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
url ='C:/Users/User/Desktop/BlackFriday.csv'
df = pd.read_csv(url)
df['City_Category'].value_counts().plot('pie')
plt.show()

# %%
#Which gender is responsible for the purchase

g = sb.FacetGrid(df,col="City_Category")
g.map(sb.barplot, "Gender", "Purchase")
plt.show()

# %%
#Which age group is responsible for this purchase
g = sb.FacetGrid(df,col="City_Category")
g.map(sb.barplot, "Age", "Purchase")
plt.show()

# %%
#can we categorize the products & total purchase on the basis of period of stay
g = sb.FacetGrid(df,col="Stay_In_Current_City_Years")
g.map(sb.barplot, "Product_Category_1", "Purchase")
plt.show()

# %%
g = sb.FacetGrid(df,col="Stay_In_Current_City_Years")
g.map(sb.barplot, "Product_Category_2", "Purchase")
plt.show()

# %%
g = sb.FacetGrid(df,col="Stay_In_Current_City_Years")
g.map(sb.barplot, "Product_Category_3", "Purchase")
plt.show()

# %%
#In which city what particular category product is selling most
g = sb.FacetGrid(df,col="City_Category")
g.map(sb.barplot, "Product_Category_1", "Purchase")
plt.show()

# %%
g = sb.FacetGrid(df,col="City_Category")
g.map(sb.barplot, "Product_Category_2", "Purchase")
plt.show()

# %%
g = sb.FacetGrid(df,col="City_Category")
g.map(sb.barplot, "Product_Category_3", "Purchase")
plt.show()
